# %%
"""
Summary:
This notebook combines the analysis and comparison of various active learning strategies 
on the classification problem of power grid security (secure / insecure).  

It includes testing of strategies (uncertainty, random, margin, entropy) under two validation scenarios:

1) random splitting of data (train_test_split)
2) sequential splitting (preserving temporal order of samples)

It saves plots with timestamps and records final results in a CSV summary table.
"""
# Out:
# '\nSummary:\nThis notebook combines the analysis and comparison of various active learning strategies \non the classification problem of power grid security (secure / insecure).  \n\nIt includes testing of strategies (uncertainty, random, margin, entropy) under two validation scenarios:\n\n1) random splitting of data (train_test_split)\n2) sequential splitting (preserving temporal order of samples)\n\nIt saves plots with timestamps and records final results in a CSV summary table.\n'

# %%
# ==============================================
# Imports & Data Loading
# ==============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import csv
import os
from time import time

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix
)

from skactiveml.classifier import SklearnClassifier
from skactiveml.utils import MISSING_LABEL
from skactiveml.pool import (
    UncertaintySampling,
    RandomSampling,
    # DensityWeightedSampling,
    # ExpectedErrorReduction
)

# %%
# ==============================================
# Load dataset
# ==============================================

data = pd.read_csv("../data/simulation_security_labels_n-1.csv")
data["status_binary"] = data["status"].map({"secure": 1, "insecure": 0})

# Drop unused columns
columns_to_drop = [
    "timestamp", "status", "status_binary",
    "max_line_loading_percent_basecase",
    "min_bus_voltage_pu_basecase",
    "max_bus_voltage_pu_basecase",
    "max_line_loading_percent_contingency",
    "min_bus_voltage_pu_contingency",
    "max_bus_voltage_pu_contingency"
]
X = data.drop(columns=columns_to_drop, errors="ignore")
y = data["status_binary"]

# %%
X
# Out:
#       load_0_p_mw  load_1_p_mw  load_2_p_mw  load_3_p_mw  load_4_p_mw  \
# 0          219.00       219.00       219.00       219.00       219.00
# 1          207.80       207.80       207.80       207.80       207.80
# 2          199.35       199.35       199.35       199.35       199.35
# 3          188.80       188.80       188.80       188.80       188.80
# 4          181.60       181.60       181.60       181.60       181.60
# ...           ...          ...          ...          ...          ...
# 8764       345.85       345.85       345.85       345.85       345.85
# 8765       329.75       329.75       329.75       329.75       329.75
# 8766       298.20       298.20       298.20       298.20       298.20
# 8767       263.05       263.05       263.05       263.05       263.05
# 8768       245.05       245.05       245.05       245.05       245.05
#
#       load_5_p_mw  load_6_p_mw  load_7_p_mw  load_8_p_mw  load_9_p_mw  ...  \
# 0          219.00       219.00       219.00       219.00       219.00  ...
# 1          207.80       207.80       207.80       207.80       207.80  ...
# 2          199.35       199.35       199.35       199.35       199.35  ...
# 3          188.80       188.80       188.80       188.80       188.80  ...
# 4          181.60       181.60       181.60       181.60       181.60  ...
# ...           ...          ...          ...          ...          ...  ...
# 8764       345.85       345.85       345.85       345.85       345.85  ...
# 8765       329.75       329.75       329.75       329.75       329.75  ...
# 8766       298.20       298.20       298.20       298.20       298.20  ...
# 8767       263.05       263.05       263.05       263.05       263.05  ...
# 8768       245.05       245.05       245.05       245.05       245.05  ...
#
#       sgen_100_p_mw  sgen_101_p_mw  sgen_102_p_mw  sgen_103_p_mw  \
# 0          9.272727       9.272727       9.272727       9.272727
# 1         10.227273      10.227273      10.227273      10.227273
# 2         11.295455      11.295455      11.295455      11.295455
# 3         13.022727      13.022727      13.022727      13.022727
# 4         14.431818      14.431818      14.431818      14.431818
# ...             ...            ...            ...            ...
# 8764       7.000000       7.000000       7.000000       7.000000
# 8765       8.045455       8.045455       8.045455       8.045455
# 8766       9.431818       9.431818       9.431818       9.431818
# 8767      11.568182      11.568182      11.568182      11.568182
# 8768      13.227273      13.227273      13.227273      13.227273
#
#       sgen_104_p_mw  sgen_105_p_mw  sgen_106_p_mw  sgen_107_p_mw  \
# 0         14.833333      14.833333      14.833333      14.833333
# 1          0.000000       0.000000       0.000000       0.000000
# 2          4.166667       4.166667       4.166667       4.166667
# 3          4.833333       4.833333       4.833333       4.833333
# 4          4.833333       4.833333       4.833333       4.833333
# ...             ...            ...            ...            ...
# 8764     214.166667     214.166667     214.166667     214.166667
# 8765     194.333333     194.333333     194.333333     194.333333
# 8766     144.333333     144.333333     144.333333     144.333333
# 8767      96.166667      96.166667      96.166667      96.166667
# 8768      74.500000      74.500000      74.500000      74.500000
#
#       sgen_108_p_mw  sgen_109_p_mw
# 0         14.833333      14.833333
# 1          0.000000       0.000000
# 2          4.166667       4.166667
# 3          4.833333       4.833333
# 4          4.833333       4.833333
# ...             ...            ...
# 8764     214.166667     214.166667
# 8765     194.333333     194.333333
# 8766     144.333333     144.333333
# 8767      96.166667      96.166667
# 8768      74.500000      74.500000
#
# [8769 rows x 265 columns]

# %%
y
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 8764    0
# 8765    0
# 8766    0
# 8767    0
# 8768    1
# Name: status_binary, Length: 8769, dtype: int64

# %%
# ==============================================
# 3) Define Splits
# ==============================================

test_size = 0.1

# Random split
X_pool_random, X_val_random, y_pool_random, y_val_random = train_test_split(
    X, y, test_size=test_size, random_state=42
)

# Sequential split (preserving time)
split_index = int((1 - test_size) * len(X))
X_pool_time = X.iloc[:split_index]
y_pool_time = y.iloc[:split_index]
X_val_time = X.iloc[split_index:]
y_val_time = y.iloc[split_index:]

# %%
# ==============================================
# 4) Active Learning Loop
# ==============================================

def run_active_learning(
    X_pool, y_pool, X_val, y_val,
    strategy_type="uncertainty",
    initial_size=100, batch_size=50, iterations=40
):
    
    print("All class labels:", np.unique(y_pool))

    base_model = RandomForestClassifier(n_estimators=100, random_state=42)
    model = SklearnClassifier(estimator=base_model)

    # choose sampling strategy
    if strategy_type == "uncertainty":
        strategy = UncertaintySampling()
    elif strategy_type == "random":
        strategy = RandomSampling()
    elif strategy_type == "entropy":
        strategy = UncertaintySampling(method="entropy")
    elif strategy_type == "margin":
        strategy = UncertaintySampling(method="margin_sampling")
    # elif strategy_type == "density":
    #     strategy = DensityWeightedSampling()
    # elif strategy_type == "expected_error":
    #     strategy = ExpectedErrorReduction()
    else:
        raise ValueError("Invalid strategy_type")

    # initialize labeled pool
    y_train = np.full(len(X_pool), MISSING_LABEL)
    initial_idx = np.random.choice(range(len(X_pool)), size=initial_size, replace=False)


    # from sklearn.model_selection import StratifiedShuffleSplit
    # sss = StratifiedShuffleSplit(n_splits=1, train_size=initial_size, random_state=42)
    # initial_idx, _ = next(sss.split(X_pool, y_pool))

    from collections import Counter
    print("Initial class distribution:", Counter(y_pool.iloc[initial_idx]))

    y_train[initial_idx] = y_pool.iloc[initial_idx]

    metrics_per_iteration = []

    for i in range(iterations):
        
        model.fit(X_pool, y_train)

        # labeled_y = y_train[y_train != -1]
        labeled_y = y_train[~pd.isna(y_train)]
        print(f"[{strategy_type.upper()}] Iter {i+1} - Classes in current training:", np.unique(labeled_y))

        y_pred = model.predict(X_val)
        y_prob = model.predict_proba(X_val)[:,1]

        # acc = accuracy_score(y_val, y_pred)
        # prec = precision_score(y_val, y_pred, zero_division=0)
        # rec = recall_score(y_val, y_pred, zero_division=0)
        # f1 = f1_score(y_val, y_pred, zero_division=0)
        # auc = roc_auc_score(y_val, y_prob)
        # cm = confusion_matrix(y_val, y_pred)

        acc = accuracy_score(y_val, y_pred)
        prec = precision_score(y_val, y_pred, zero_division=0, average="macro", pos_label=1)
        rec = recall_score(y_val, y_pred, zero_division=0, average="macro", pos_label=1)
        f1 = f1_score(y_val, y_pred, zero_division=0, average="macro", pos_label=1)
        auc = roc_auc_score(y_val, y_prob)
        cm = confusion_matrix(y_val, y_pred)

        metrics_per_iteration.append({
            "iteration": i+1,
            "accuracy": acc,
            "precision": prec,
            "recall": rec,
            "f1": f1,
            "roc_auc": auc,
            "confusion_matrix": cm.tolist()
        })

        print(f"Iter {i+1} [{strategy_type}] - acc:{acc:.4f}, f1:{f1:.4f}, auc:{auc:.4f}")

        if len(X_pool) < batch_size:
            print("No more samples to query, stopping early.")
            break

        if strategy_type in ["uncertainty", "entropy", "margin"]: # "density", "expected_error"]
            print(f"X_pool shape: {X_pool.shape}, y_train unlabeled: {np.sum(pd.isna(y_train))}")

            print(f"Batch size: {batch_size}, X_pool shape: {X_pool.shape}")
            print(f"Unlabeled in y_train: {np.sum(pd.isna(y_train))}")
            print(f"Labeled: {np.sum(~pd.isna(y_train))}")
            print(f"Candidate indices: {len(np.arange(len(X_pool)))}")


            # Reset indices to avoid index mismatch issues
            X_pool = X_pool.reset_index(drop=True)
            y_pool = y_pool.reset_index(drop=True)
            y_train = pd.Series(y_train).reset_index(drop=True).to_numpy()

            # Filter candidates (only unlabeled ones)
            candidates = np.where(pd.isna(y_train))[0]

            # Call strategy
            query_idx, scores = strategy.query(X_pool, y=y_train, clf=model, candidates=candidates, batch_size=batch_size, return_utilities=True)

            print("Top 5 selected samples and their scores:")
            for idx, score in zip(query_idx[:5], scores[:5]):
                print(f"  idx={idx}, type={type(score)}, value={score}")
        else:
            candidates = np.where(pd.isna(y_train))[0]
            query_idx, scores = strategy.query(X_pool, y=y_train, candidates=candidates, batch_size=batch_size, return_utilities=True)

            print("Top 5 randomly selected samples and their scores:")
            
            for idx, score in zip(query_idx[:5], scores[:5]):
                print(f"  idx={idx}, type={type(score)}, value={score}")

        y_train[query_idx] = y_pool.iloc[query_idx]

    return metrics_per_iteration

# %%
# ==============================================
# 5) Run Experiments
# ==============================================

initial_size = 100
batch_size = 50
iterations = 40 #40

strategies_list = [
    "uncertainty", 
    "random", 
    "entropy", 
    "margin", 
    # "density", 
    # "expected_error"
]

results_random = {}
results_time = {}

start_time = time()

for strat in strategies_list:
    results_random[strat] = run_active_learning(
        X_pool_random.copy(), y_pool_random.copy(), X_val_random, y_val_random,
        strategy_type=strat,
        initial_size=initial_size,
        batch_size=batch_size,
        iterations=iterations
    )
    results_time[strat] = run_active_learning(
        X_pool_time.copy(), y_pool_time.copy(), X_val_time, y_val_time,
        strategy_type=strat,
        initial_size=initial_size,
        batch_size=batch_size,
        iterations=iterations
    )

end_time = time()
duration = round(end_time - start_time, 2)
# Out:
# All class labels: [0 1]
# Initial class distribution: Counter({1: 56, 0: 44})
# [UNCERTAINTY] Iter 1 - Classes in current training: [0. 1.]
# Iter 1 [uncertainty] - acc:0.8312, f1:0.8304, auc:0.9139
# X_pool shape: (7892, 265), y_train unlabeled: 7792
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7792
# Labeled: 100
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2901, type=<class 'numpy.ndarray'>, value=[0.01 0.21 0.05 ... 0.01 0.24 0.4 ]
#   idx=3679, type=<class 'numpy.ndarray'>, value=[0.01 0.21 0.05 ... 0.01 0.24 0.4 ]
#   idx=139, type=<class 'numpy.ndarray'>, value=[0.01 0.21 0.05 ... 0.01 0.24 0.4 ]
#   idx=5030, type=<class 'numpy.ndarray'>, value=[0.01 0.21 0.05 ... 0.01 0.24 0.4 ]
#   idx=4192, type=<class 'numpy.ndarray'>, value=[0.01 0.21 0.05 ... 0.01 0.24 0.4 ]
# [UNCERTAINTY] Iter 2 - Classes in current training: [0. 1.]
# Iter 2 [uncertainty] - acc:0.8529, f1:0.8529, auc:0.9340
# X_pool shape: (7892, 265), y_train unlabeled: 7742
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7742
# Labeled: 150
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7169, type=<class 'numpy.ndarray'>, value=[0.02 0.2  0.03 ... 0.01 0.22 0.45]
#   idx=7698, type=<class 'numpy.ndarray'>, value=[0.02 0.2  0.03 ... 0.01 0.22 0.45]
#   idx=6420, type=<class 'numpy.ndarray'>, value=[0.02 0.2  0.03 ... 0.01 0.22 0.45]
#   idx=7709, type=<class 'numpy.ndarray'>, value=[0.02 0.2  0.03 ... 0.01 0.22 0.45]
#   idx=4409, type=<class 'numpy.ndarray'>, value=[0.02 0.2  0.03 ... 0.01 0.22 0.45]
# [UNCERTAINTY] Iter 3 - Classes in current training: [0. 1.]
# Iter 3 [uncertainty] - acc:0.8689, f1:0.8688, auc:0.9441
# X_pool shape: (7892, 265), y_train unlabeled: 7692
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7692
# Labeled: 200
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2188, type=<class 'numpy.ndarray'>, value=[0.02 0.17 0.12 ... 0.02 0.31 0.32]
#   idx=6580, type=<class 'numpy.ndarray'>, value=[0.02 0.17 0.12 ... 0.02 0.31 0.32]
#   idx=5852, type=<class 'numpy.ndarray'>, value=[0.02 0.17 0.12 ... 0.02 0.31 0.32]
#   idx=2698, type=<class 'numpy.ndarray'>, value=[0.02 0.17 0.12 ... 0.02 0.31 0.32]
#   idx=776, type=<class 'numpy.ndarray'>, value=[0.02 0.17 0.12 ... 0.02 0.31 0.32]
# [UNCERTAINTY] Iter 4 - Classes in current training: [0. 1.]
# Iter 4 [uncertainty] - acc:0.8905, f1:0.8905, auc:0.9520
# X_pool shape: (7892, 265), y_train unlabeled: 7642
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7642
# Labeled: 250
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=1980, type=<class 'numpy.ndarray'>, value=[0.   0.12 0.07 ... 0.05 0.18 0.42]
#   idx=4707, type=<class 'numpy.ndarray'>, value=[0.   0.12 0.07 ... 0.05 0.18 0.42]
#   idx=7421, type=<class 'numpy.ndarray'>, value=[0.   0.12 0.07 ... 0.05 0.18 0.42]
#   idx=5799, type=<class 'numpy.ndarray'>, value=[0.   0.12 0.07 ... 0.05 0.18 0.42]
#   idx=1382, type=<class 'numpy.ndarray'>, value=[0.   0.12 0.07 ... 0.05 0.18 0.42]
# [UNCERTAINTY] Iter 5 - Classes in current training: [0. 1.]
# Iter 5 [uncertainty] - acc:0.8905, f1:0.8905, auc:0.9544
# X_pool shape: (7892, 265), y_train unlabeled: 7592
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7592
# Labeled: 300
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6175, type=<class 'numpy.ndarray'>, value=[0.01 0.11 0.09 ... 0.08 0.2  0.13]
#   idx=3874, type=<class 'numpy.ndarray'>, value=[0.01 0.11 0.09 ... 0.08 0.2  0.13]
#   idx=4654, type=<class 'numpy.ndarray'>, value=[0.01 0.11 0.09 ... 0.08 0.2  0.13]
#   idx=4295, type=<class 'numpy.ndarray'>, value=[0.01 0.11 0.09 ... 0.08 0.2  0.13]
#   idx=3841, type=<class 'numpy.ndarray'>, value=[0.01 0.11 0.09 ... 0.08 0.2  0.13]
# [UNCERTAINTY] Iter 6 - Classes in current training: [0. 1.]
# Iter 6 [uncertainty] - acc:0.9042, f1:0.9042, auc:0.9628
# X_pool shape: (7892, 265), y_train unlabeled: 7542
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7542
# Labeled: 350
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=1972, type=<class 'numpy.ndarray'>, value=[0.01 0.12 0.06 ... 0.07 0.23 0.24]
#   idx=7428, type=<class 'numpy.ndarray'>, value=[0.01 0.12 0.06 ... 0.07 0.23 0.24]
#   idx=2813, type=<class 'numpy.ndarray'>, value=[0.01 0.12 0.06 ... 0.07 0.23 0.24]
#   idx=4130, type=<class 'numpy.ndarray'>, value=[0.01 0.12 0.06 ... 0.07 0.23 0.24]
#   idx=715, type=<class 'numpy.ndarray'>, value=[0.01 0.12 0.06 ... 0.07 0.23 0.24]
# [UNCERTAINTY] Iter 7 - Classes in current training: [0. 1.]
# Iter 7 [uncertainty] - acc:0.9236, f1:0.9236, auc:0.9679
# X_pool shape: (7892, 265), y_train unlabeled: 7492
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7492
# Labeled: 400
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7528, type=<class 'numpy.ndarray'>, value=[0.01 0.22 0.08 ... 0.07 0.25 0.31]
#   idx=5099, type=<class 'numpy.ndarray'>, value=[0.01 0.22 0.08 ... 0.07 0.25 0.31]
#   idx=2888, type=<class 'numpy.ndarray'>, value=[0.01 0.22 0.08 ... 0.07 0.25 0.31]
#   idx=945, type=<class 'numpy.ndarray'>, value=[0.01 0.22 0.08 ... 0.07 0.25 0.31]
#   idx=658, type=<class 'numpy.ndarray'>, value=[0.01 0.22 0.08 ... 0.07 0.25 0.31]
# [UNCERTAINTY] Iter 8 - Classes in current training: [0. 1.]
# Iter 8 [uncertainty] - acc:0.9236, f1:0.9236, auc:0.9705
# X_pool shape: (7892, 265), y_train unlabeled: 7442
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7442
# Labeled: 450
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=613, type=<class 'numpy.ndarray'>, value=[0.02 0.16 0.08 ... 0.08 0.27 0.37]
#   idx=4742, type=<class 'numpy.ndarray'>, value=[0.02 0.16 0.08 ... 0.08 0.27 0.37]
#   idx=4304, type=<class 'numpy.ndarray'>, value=[0.02 0.16 0.08 ... 0.08 0.27 0.37]
#   idx=3414, type=<class 'numpy.ndarray'>, value=[0.02 0.16 0.08 ... 0.08 0.27 0.37]
#   idx=6987, type=<class 'numpy.ndarray'>, value=[0.02 0.16 0.08 ... 0.08 0.27 0.37]
# [UNCERTAINTY] Iter 9 - Classes in current training: [0. 1.]
# Iter 9 [uncertainty] - acc:0.9247, f1:0.9247, auc:0.9732
# X_pool shape: (7892, 265), y_train unlabeled: 7392
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7392
# Labeled: 500
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4213, type=<class 'numpy.ndarray'>, value=[0.01 0.33 0.09 ... 0.07 0.24 0.45]
#   idx=6652, type=<class 'numpy.ndarray'>, value=[0.01 0.33 0.09 ... 0.07 0.24 0.45]
#   idx=5174, type=<class 'numpy.ndarray'>, value=[0.01 0.33 0.09 ... 0.07 0.24 0.45]
#   idx=499, type=<class 'numpy.ndarray'>, value=[0.01 0.33 0.09 ... 0.07 0.24 0.45]
#   idx=7432, type=<class 'numpy.ndarray'>, value=[0.01 0.33 0.09 ... 0.07 0.24 0.45]
# [UNCERTAINTY] Iter 10 - Classes in current training: [0. 1.]
# Iter 10 [uncertainty] - acc:0.9282, f1:0.9282, auc:0.9738
# X_pool shape: (7892, 265), y_train unlabeled: 7342
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7342
# Labeled: 550
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7550, type=<class 'numpy.ndarray'>, value=[0.   0.43 0.07 ... 0.06 0.15 0.33]
#   idx=5290, type=<class 'numpy.ndarray'>, value=[0.   0.43 0.07 ... 0.06 0.15 0.33]
#   idx=2943, type=<class 'numpy.ndarray'>, value=[0.   0.43 0.07 ... 0.06 0.15 0.33]
#   idx=486, type=<class 'numpy.ndarray'>, value=[0.   0.43 0.07 ... 0.06 0.15 0.33]
#   idx=6292, type=<class 'numpy.ndarray'>, value=[0.   0.43 0.07 ... 0.06 0.15 0.33]
# [UNCERTAINTY] Iter 11 - Classes in current training: [0. 1.]
# Iter 11 [uncertainty] - acc:0.9190, f1:0.9190, auc:0.9717
# X_pool shape: (7892, 265), y_train unlabeled: 7292
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7292
# Labeled: 600
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2002, type=<class 'numpy.ndarray'>, value=[0.01 0.46 0.11 ... 0.06 0.26 0.38]
#   idx=4272, type=<class 'numpy.ndarray'>, value=[0.01 0.46 0.11 ... 0.06 0.26 0.38]
#   idx=2107, type=<class 'numpy.ndarray'>, value=[0.01 0.46 0.11 ... 0.06 0.26 0.38]
#   idx=6269, type=<class 'numpy.ndarray'>, value=[0.01 0.46 0.11 ... 0.06 0.26 0.38]
#   idx=1351, type=<class 'numpy.ndarray'>, value=[0.01 0.46 0.11 ... 0.06 0.26 0.38]
# [UNCERTAINTY] Iter 12 - Classes in current training: [0. 1.]
# Iter 12 [uncertainty] - acc:0.9213, f1:0.9213, auc:0.9758
# X_pool shape: (7892, 265), y_train unlabeled: 7242
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7242
# Labeled: 650
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4281, type=<class 'numpy.ndarray'>, value=[0.03 0.24 0.09 ... 0.05 0.23 0.47]
#   idx=7220, type=<class 'numpy.ndarray'>, value=[0.03 0.24 0.09 ... 0.05 0.23 0.47]
#   idx=4120, type=<class 'numpy.ndarray'>, value=[0.03 0.24 0.09 ... 0.05 0.23 0.47]
#   idx=1116, type=<class 'numpy.ndarray'>, value=[0.03 0.24 0.09 ... 0.05 0.23 0.47]
#   idx=6475, type=<class 'numpy.ndarray'>, value=[0.03 0.24 0.09 ... 0.05 0.23 0.47]
# [UNCERTAINTY] Iter 13 - Classes in current training: [0. 1.]
# Iter 13 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9782
# X_pool shape: (7892, 265), y_train unlabeled: 7192
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7192
# Labeled: 700
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6951, type=<class 'numpy.ndarray'>, value=[0.02 0.26 0.08 ... 0.06 0.22 0.28]
#   idx=3219, type=<class 'numpy.ndarray'>, value=[0.02 0.26 0.08 ... 0.06 0.22 0.28]
#   idx=692, type=<class 'numpy.ndarray'>, value=[0.02 0.26 0.08 ... 0.06 0.22 0.28]
#   idx=5422, type=<class 'numpy.ndarray'>, value=[0.02 0.26 0.08 ... 0.06 0.22 0.28]
#   idx=6274, type=<class 'numpy.ndarray'>, value=[0.02 0.26 0.08 ... 0.06 0.22 0.28]
# [UNCERTAINTY] Iter 14 - Classes in current training: [0. 1.]
# Iter 14 [uncertainty] - acc:0.9407, f1:0.9407, auc:0.9812
# X_pool shape: (7892, 265), y_train unlabeled: 7142
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7142
# Labeled: 750
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2846, type=<class 'numpy.ndarray'>, value=[0.03 0.25 0.17 ... 0.09 0.29 0.21]
#   idx=5924, type=<class 'numpy.ndarray'>, value=[0.03 0.25 0.17 ... 0.09 0.29 0.21]
#   idx=7682, type=<class 'numpy.ndarray'>, value=[0.03 0.25 0.17 ... 0.09 0.29 0.21]
#   idx=1918, type=<class 'numpy.ndarray'>, value=[0.03 0.25 0.17 ... 0.09 0.29 0.21]
#   idx=476, type=<class 'numpy.ndarray'>, value=[0.03 0.25 0.17 ... 0.09 0.29 0.21]
# [UNCERTAINTY] Iter 15 - Classes in current training: [0. 1.]
# Iter 15 [uncertainty] - acc:0.9396, f1:0.9396, auc:0.9799
# X_pool shape: (7892, 265), y_train unlabeled: 7092
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7092
# Labeled: 800
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4326, type=<class 'numpy.ndarray'>, value=[0.03 0.2  0.09 ... 0.08 0.25 0.22]
#   idx=7814, type=<class 'numpy.ndarray'>, value=[0.03 0.2  0.09 ... 0.08 0.25 0.22]
#   idx=3129, type=<class 'numpy.ndarray'>, value=[0.03 0.2  0.09 ... 0.08 0.25 0.22]
#   idx=4801, type=<class 'numpy.ndarray'>, value=[0.03 0.2  0.09 ... 0.08 0.25 0.22]
#   idx=5710, type=<class 'numpy.ndarray'>, value=[0.03 0.2  0.09 ... 0.08 0.25 0.22]
# [UNCERTAINTY] Iter 16 - Classes in current training: [0. 1.]
# Iter 16 [uncertainty] - acc:0.9384, f1:0.9384, auc:0.9797
# X_pool shape: (7892, 265), y_train unlabeled: 7042
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7042
# Labeled: 850
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=5014, type=<class 'numpy.ndarray'>, value=[0.03 0.18 0.07 ... 0.06 0.18 0.21]
#   idx=1579, type=<class 'numpy.ndarray'>, value=[0.03 0.18 0.07 ... 0.06 0.18 0.21]
#   idx=2533, type=<class 'numpy.ndarray'>, value=[0.03 0.18 0.07 ... 0.06 0.18 0.21]
#   idx=3566, type=<class 'numpy.ndarray'>, value=[0.03 0.18 0.07 ... 0.06 0.18 0.21]
#   idx=352, type=<class 'numpy.ndarray'>, value=[0.03 0.18 0.07 ... 0.06 0.18 0.21]
# [UNCERTAINTY] Iter 17 - Classes in current training: [0. 1.]
# Iter 17 [uncertainty] - acc:0.9350, f1:0.9350, auc:0.9812
# X_pool shape: (7892, 265), y_train unlabeled: 6992
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6992
# Labeled: 900
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6458, type=<class 'numpy.ndarray'>, value=[0.03 0.26 0.09 ... 0.06 0.24 0.15]
#   idx=695, type=<class 'numpy.ndarray'>, value=[0.03 0.26 0.09 ... 0.06 0.24 0.15]
#   idx=3618, type=<class 'numpy.ndarray'>, value=[0.03 0.26 0.09 ... 0.06 0.24 0.15]
#   idx=3987, type=<class 'numpy.ndarray'>, value=[0.03 0.26 0.09 ... 0.06 0.24 0.15]
#   idx=7386, type=<class 'numpy.ndarray'>, value=[0.03 0.26 0.09 ... 0.06 0.24 0.15]
# [UNCERTAINTY] Iter 18 - Classes in current training: [0. 1.]
# Iter 18 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9816
# X_pool shape: (7892, 265), y_train unlabeled: 6942
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6942
# Labeled: 950
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=924, type=<class 'numpy.ndarray'>, value=[0.01 0.13 0.16 ... 0.08 0.28 0.27]
#   idx=5712, type=<class 'numpy.ndarray'>, value=[0.01 0.13 0.16 ... 0.08 0.28 0.27]
#   idx=7120, type=<class 'numpy.ndarray'>, value=[0.01 0.13 0.16 ... 0.08 0.28 0.27]
#   idx=384, type=<class 'numpy.ndarray'>, value=[0.01 0.13 0.16 ... 0.08 0.28 0.27]
#   idx=2740, type=<class 'numpy.ndarray'>, value=[0.01 0.13 0.16 ... 0.08 0.28 0.27]
# [UNCERTAINTY] Iter 19 - Classes in current training: [0. 1.]
# Iter 19 [uncertainty] - acc:0.9453, f1:0.9453, auc:0.9831
# X_pool shape: (7892, 265), y_train unlabeled: 6892
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6892
# Labeled: 1000
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=1585, type=<class 'numpy.ndarray'>, value=[0.06 0.27 0.09 ... 0.07 0.2  0.2 ]
#   idx=302, type=<class 'numpy.ndarray'>, value=[0.06 0.27 0.09 ... 0.07 0.2  0.2 ]
#   idx=5268, type=<class 'numpy.ndarray'>, value=[0.06 0.27 0.09 ... 0.07 0.2  0.2 ]
#   idx=4948, type=<class 'numpy.ndarray'>, value=[0.06 0.27 0.09 ... 0.07 0.2  0.2 ]
#   idx=1930, type=<class 'numpy.ndarray'>, value=[0.06 0.27 0.09 ... 0.07 0.2  0.2 ]
# [UNCERTAINTY] Iter 20 - Classes in current training: [0. 1.]
# Iter 20 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9820
# X_pool shape: (7892, 265), y_train unlabeled: 6842
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6842
# Labeled: 1050
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2254, type=<class 'numpy.ndarray'>, value=[0.02 0.25 0.07 ... 0.03 0.2  0.36]
#   idx=7209, type=<class 'numpy.ndarray'>, value=[0.02 0.25 0.07 ... 0.03 0.2  0.36]
#   idx=7370, type=<class 'numpy.ndarray'>, value=[0.02 0.25 0.07 ... 0.03 0.2  0.36]
#   idx=614, type=<class 'numpy.ndarray'>, value=[0.02 0.25 0.07 ... 0.03 0.2  0.36]
#   idx=3930, type=<class 'numpy.ndarray'>, value=[0.02 0.25 0.07 ... 0.03 0.2  0.36]
# [UNCERTAINTY] Iter 21 - Classes in current training: [0. 1.]
# Iter 21 [uncertainty] - acc:0.9396, f1:0.9396, auc:0.9825
# X_pool shape: (7892, 265), y_train unlabeled: 6792
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6792
# Labeled: 1100
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6690, type=<class 'numpy.ndarray'>, value=[0.07 0.24 0.18 ... 0.16 0.19 0.25]
#   idx=1497, type=<class 'numpy.ndarray'>, value=[0.07 0.24 0.18 ... 0.16 0.19 0.25]
#   idx=6022, type=<class 'numpy.ndarray'>, value=[0.07 0.24 0.18 ... 0.16 0.19 0.25]
#   idx=7059, type=<class 'numpy.ndarray'>, value=[0.07 0.24 0.18 ... 0.16 0.19 0.25]
#   idx=6155, type=<class 'numpy.ndarray'>, value=[0.07 0.24 0.18 ... 0.16 0.19 0.25]
# [UNCERTAINTY] Iter 22 - Classes in current training: [0. 1.]
# Iter 22 [uncertainty] - acc:0.9464, f1:0.9464, auc:0.9843
# X_pool shape: (7892, 265), y_train unlabeled: 6742
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6742
# Labeled: 1150
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=1557, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.09 ... 0.07 0.21 0.21]
#   idx=2204, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.09 ... 0.07 0.21 0.21]
#   idx=4246, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.09 ... 0.07 0.21 0.21]
#   idx=4564, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.09 ... 0.07 0.21 0.21]
#   idx=1249, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.09 ... 0.07 0.21 0.21]
# [UNCERTAINTY] Iter 23 - Classes in current training: [0. 1.]
# Iter 23 [uncertainty] - acc:0.9464, f1:0.9464, auc:0.9844
# X_pool shape: (7892, 265), y_train unlabeled: 6692
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6692
# Labeled: 1200
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=5311, type=<class 'numpy.ndarray'>, value=[0.06 0.29 0.16 ... 0.05 0.25 0.21]
#   idx=2378, type=<class 'numpy.ndarray'>, value=[0.06 0.29 0.16 ... 0.05 0.25 0.21]
#   idx=874, type=<class 'numpy.ndarray'>, value=[0.06 0.29 0.16 ... 0.05 0.25 0.21]
#   idx=2839, type=<class 'numpy.ndarray'>, value=[0.06 0.29 0.16 ... 0.05 0.25 0.21]
#   idx=5746, type=<class 'numpy.ndarray'>, value=[0.06 0.29 0.16 ... 0.05 0.25 0.21]
# [UNCERTAINTY] Iter 24 - Classes in current training: [0. 1.]
# Iter 24 [uncertainty] - acc:0.9510, f1:0.9510, auc:0.9862
# X_pool shape: (7892, 265), y_train unlabeled: 6642
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6642
# Labeled: 1250
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3284, type=<class 'numpy.ndarray'>, value=[0.07 0.26 0.17 ... 0.13 0.19 0.13]
#   idx=4418, type=<class 'numpy.ndarray'>, value=[0.07 0.26 0.17 ... 0.13 0.19 0.13]
#   idx=6562, type=<class 'numpy.ndarray'>, value=[0.07 0.26 0.17 ... 0.13 0.19 0.13]
#   idx=6619, type=<class 'numpy.ndarray'>, value=[0.07 0.26 0.17 ... 0.13 0.19 0.13]
#   idx=3467, type=<class 'numpy.ndarray'>, value=[0.07 0.26 0.17 ... 0.13 0.19 0.13]
# [UNCERTAINTY] Iter 25 - Classes in current training: [0. 1.]
# Iter 25 [uncertainty] - acc:0.9475, f1:0.9475, auc:0.9848
# X_pool shape: (7892, 265), y_train unlabeled: 6592
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6592
# Labeled: 1300
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7154, type=<class 'numpy.ndarray'>, value=[0.06 0.28 0.16 ... 0.12 0.14 0.22]
#   idx=6100, type=<class 'numpy.ndarray'>, value=[0.06 0.28 0.16 ... 0.12 0.14 0.22]
#   idx=1407, type=<class 'numpy.ndarray'>, value=[0.06 0.28 0.16 ... 0.12 0.14 0.22]
#   idx=2812, type=<class 'numpy.ndarray'>, value=[0.06 0.28 0.16 ... 0.12 0.14 0.22]
#   idx=977, type=<class 'numpy.ndarray'>, value=[0.06 0.28 0.16 ... 0.12 0.14 0.22]
# [UNCERTAINTY] Iter 26 - Classes in current training: [0. 1.]
# Iter 26 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9847
# X_pool shape: (7892, 265), y_train unlabeled: 6542
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6542
# Labeled: 1350
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4235, type=<class 'numpy.ndarray'>, value=[0.06 0.26 0.2  ... 0.1  0.18 0.17]
#   idx=7429, type=<class 'numpy.ndarray'>, value=[0.06 0.26 0.2  ... 0.1  0.18 0.17]
#   idx=561, type=<class 'numpy.ndarray'>, value=[0.06 0.26 0.2  ... 0.1  0.18 0.17]
#   idx=5394, type=<class 'numpy.ndarray'>, value=[0.06 0.26 0.2  ... 0.1  0.18 0.17]
#   idx=425, type=<class 'numpy.ndarray'>, value=[0.06 0.26 0.2  ... 0.1  0.18 0.17]
# [UNCERTAINTY] Iter 27 - Classes in current training: [0. 1.]
# Iter 27 [uncertainty] - acc:0.9384, f1:0.9384, auc:0.9840
# X_pool shape: (7892, 265), y_train unlabeled: 6492
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6492
# Labeled: 1400
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=583, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.22 ... 0.17 0.15 0.23]
#   idx=5672, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.22 ... 0.17 0.15 0.23]
#   idx=1735, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.22 ... 0.17 0.15 0.23]
#   idx=6551, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.22 ... 0.17 0.15 0.23]
#   idx=6447, type=<class 'numpy.ndarray'>, value=[0.03 0.23 0.22 ... 0.17 0.15 0.23]
# [UNCERTAINTY] Iter 28 - Classes in current training: [0. 1.]
# Iter 28 [uncertainty] - acc:0.9464, f1:0.9464, auc:0.9844
# X_pool shape: (7892, 265), y_train unlabeled: 6442
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6442
# Labeled: 1450
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3429, type=<class 'numpy.ndarray'>, value=[0.1  0.19 0.15 ... 0.05 0.06 0.18]
#   idx=1380, type=<class 'numpy.ndarray'>, value=[0.1  0.19 0.15 ... 0.05 0.06 0.18]
#   idx=2397, type=<class 'numpy.ndarray'>, value=[0.1  0.19 0.15 ... 0.05 0.06 0.18]
#   idx=741, type=<class 'numpy.ndarray'>, value=[0.1  0.19 0.15 ... 0.05 0.06 0.18]
#   idx=6996, type=<class 'numpy.ndarray'>, value=[0.1  0.19 0.15 ... 0.05 0.06 0.18]
# [UNCERTAINTY] Iter 29 - Classes in current training: [0. 1.]
# Iter 29 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9837
# X_pool shape: (7892, 265), y_train unlabeled: 6392
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6392
# Labeled: 1500
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=631, type=<class 'numpy.ndarray'>, value=[0.09 0.09 0.22 ... 0.14 0.14 0.14]
#   idx=1499, type=<class 'numpy.ndarray'>, value=[0.09 0.09 0.22 ... 0.14 0.14 0.14]
#   idx=3579, type=<class 'numpy.ndarray'>, value=[0.09 0.09 0.22 ... 0.14 0.14 0.14]
#   idx=5487, type=<class 'numpy.ndarray'>, value=[0.09 0.09 0.22 ... 0.14 0.14 0.14]
#   idx=6775, type=<class 'numpy.ndarray'>, value=[0.09 0.09 0.22 ... 0.14 0.14 0.14]
# [UNCERTAINTY] Iter 30 - Classes in current training: [0. 1.]
# Iter 30 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9851
# X_pool shape: (7892, 265), y_train unlabeled: 6342
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6342
# Labeled: 1550
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4003, type=<class 'numpy.ndarray'>, value=[0.01 0.08 0.15 ... 0.13 0.11 0.16]
#   idx=3646, type=<class 'numpy.ndarray'>, value=[0.01 0.08 0.15 ... 0.13 0.11 0.16]
#   idx=6668, type=<class 'numpy.ndarray'>, value=[0.01 0.08 0.15 ... 0.13 0.11 0.16]
#   idx=4060, type=<class 'numpy.ndarray'>, value=[0.01 0.08 0.15 ... 0.13 0.11 0.16]
#   idx=3977, type=<class 'numpy.ndarray'>, value=[0.01 0.08 0.15 ... 0.13 0.11 0.16]
# [UNCERTAINTY] Iter 31 - Classes in current training: [0. 1.]
# Iter 31 [uncertainty] - acc:0.9407, f1:0.9407, auc:0.9857
# X_pool shape: (7892, 265), y_train unlabeled: 6292
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6292
# Labeled: 1600
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3929, type=<class 'numpy.ndarray'>, value=[0.08 0.05 0.27 ... 0.16 0.14 0.19]
#   idx=5543, type=<class 'numpy.ndarray'>, value=[0.08 0.05 0.27 ... 0.16 0.14 0.19]
#   idx=2046, type=<class 'numpy.ndarray'>, value=[0.08 0.05 0.27 ... 0.16 0.14 0.19]
#   idx=4682, type=<class 'numpy.ndarray'>, value=[0.08 0.05 0.27 ... 0.16 0.14 0.19]
#   idx=687, type=<class 'numpy.ndarray'>, value=[0.08 0.05 0.27 ... 0.16 0.14 0.19]
# [UNCERTAINTY] Iter 32 - Classes in current training: [0. 1.]
# Iter 32 [uncertainty] - acc:0.9418, f1:0.9418, auc:0.9861
# X_pool shape: (7892, 265), y_train unlabeled: 6242
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6242
# Labeled: 1650
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6666, type=<class 'numpy.ndarray'>, value=[0.08 0.03 0.18 ... 0.12 0.1  0.16]
#   idx=4905, type=<class 'numpy.ndarray'>, value=[0.08 0.03 0.18 ... 0.12 0.1  0.16]
#   idx=2307, type=<class 'numpy.ndarray'>, value=[0.08 0.03 0.18 ... 0.12 0.1  0.16]
#   idx=760, type=<class 'numpy.ndarray'>, value=[0.08 0.03 0.18 ... 0.12 0.1  0.16]
#   idx=536, type=<class 'numpy.ndarray'>, value=[0.08 0.03 0.18 ... 0.12 0.1  0.16]
# [UNCERTAINTY] Iter 33 - Classes in current training: [0. 1.]
# Iter 33 [uncertainty] - acc:0.9418, f1:0.9418, auc:0.9847
# X_pool shape: (7892, 265), y_train unlabeled: 6192
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6192
# Labeled: 1700
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7242, type=<class 'numpy.ndarray'>, value=[0.14 0.1  0.2  ... 0.18 0.15 0.12]
#   idx=6536, type=<class 'numpy.ndarray'>, value=[0.14 0.1  0.2  ... 0.18 0.15 0.12]
#   idx=1780, type=<class 'numpy.ndarray'>, value=[0.14 0.1  0.2  ... 0.18 0.15 0.12]
#   idx=3237, type=<class 'numpy.ndarray'>, value=[0.14 0.1  0.2  ... 0.18 0.15 0.12]
#   idx=7763, type=<class 'numpy.ndarray'>, value=[0.14 0.1  0.2  ... 0.18 0.15 0.12]
# [UNCERTAINTY] Iter 34 - Classes in current training: [0. 1.]
# Iter 34 [uncertainty] - acc:0.9407, f1:0.9407, auc:0.9818
# X_pool shape: (7892, 265), y_train unlabeled: 6142
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6142
# Labeled: 1750
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4632, type=<class 'numpy.ndarray'>, value=[0.05 0.1  0.16 ... 0.13 0.12 0.11]
#   idx=3787, type=<class 'numpy.ndarray'>, value=[0.05 0.1  0.16 ... 0.13 0.12 0.11]
#   idx=5784, type=<class 'numpy.ndarray'>, value=[0.05 0.1  0.16 ... 0.13 0.12 0.11]
#   idx=68, type=<class 'numpy.ndarray'>, value=[0.05 0.1  0.16 ... 0.13 0.12 0.11]
#   idx=587, type=<class 'numpy.ndarray'>, value=[0.05 0.1  0.16 ... 0.13 0.12 0.11]
# [UNCERTAINTY] Iter 35 - Classes in current training: [0. 1.]
# Iter 35 [uncertainty] - acc:0.9418, f1:0.9418, auc:0.9829
# X_pool shape: (7892, 265), y_train unlabeled: 6092
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6092
# Labeled: 1800
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=534, type=<class 'numpy.ndarray'>, value=[0.08 0.07 0.13 ... 0.12 0.11 0.23]
#   idx=2618, type=<class 'numpy.ndarray'>, value=[0.08 0.07 0.13 ... 0.12 0.11 0.23]
#   idx=2699, type=<class 'numpy.ndarray'>, value=[0.08 0.07 0.13 ... 0.12 0.11 0.23]
#   idx=4914, type=<class 'numpy.ndarray'>, value=[0.08 0.07 0.13 ... 0.12 0.11 0.23]
#   idx=1594, type=<class 'numpy.ndarray'>, value=[0.08 0.07 0.13 ... 0.12 0.11 0.23]
# [UNCERTAINTY] Iter 36 - Classes in current training: [0. 1.]
# Iter 36 [uncertainty] - acc:0.9418, f1:0.9418, auc:0.9823
# X_pool shape: (7892, 265), y_train unlabeled: 6042
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6042
# Labeled: 1850
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6658, type=<class 'numpy.ndarray'>, value=[0.15 0.14 0.12 ... 0.13 0.1  0.09]
#   idx=272, type=<class 'numpy.ndarray'>, value=[0.15 0.14 0.12 ... 0.13 0.1  0.09]
#   idx=4452, type=<class 'numpy.ndarray'>, value=[0.15 0.14 0.12 ... 0.13 0.1  0.09]
#   idx=6611, type=<class 'numpy.ndarray'>, value=[0.15 0.14 0.12 ... 0.13 0.1  0.09]
#   idx=3847, type=<class 'numpy.ndarray'>, value=[0.15 0.14 0.12 ... 0.13 0.1  0.09]
# [UNCERTAINTY] Iter 37 - Classes in current training: [0. 1.]
# Iter 37 [uncertainty] - acc:0.9487, f1:0.9487, auc:0.9830
# X_pool shape: (7892, 265), y_train unlabeled: 5992
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 5992
# Labeled: 1900
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=259, type=<class 'numpy.ndarray'>, value=[0.03 0.07 0.13 ... 0.11 0.1  0.12]
#   idx=5829, type=<class 'numpy.ndarray'>, value=[0.03 0.07 0.13 ... 0.11 0.1  0.12]
#   idx=6452, type=<class 'numpy.ndarray'>, value=[0.03 0.07 0.13 ... 0.11 0.1  0.12]
#   idx=3518, type=<class 'numpy.ndarray'>, value=[0.03 0.07 0.13 ... 0.11 0.1  0.12]
#   idx=5753, type=<class 'numpy.ndarray'>, value=[0.03 0.07 0.13 ... 0.11 0.1  0.12]
# [UNCERTAINTY] Iter 38 - Classes in current training: [0. 1.]
# Iter 38 [uncertainty] - acc:0.9453, f1:0.9453, auc:0.9857
# X_pool shape: (7892, 265), y_train unlabeled: 5942
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 5942
# Labeled: 1950
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=149, type=<class 'numpy.ndarray'>, value=[0.03 0.1  0.1  ... 0.08 0.18 0.12]
#   idx=6034, type=<class 'numpy.ndarray'>, value=[0.03 0.1  0.1  ... 0.08 0.18 0.12]
#   idx=4795, type=<class 'numpy.ndarray'>, value=[0.03 0.1  0.1  ... 0.08 0.18 0.12]
#   idx=784, type=<class 'numpy.ndarray'>, value=[0.03 0.1  0.1  ... 0.08 0.18 0.12]
#   idx=1079, type=<class 'numpy.ndarray'>, value=[0.03 0.1  0.1  ... 0.08 0.18 0.12]
# [UNCERTAINTY] Iter 39 - Classes in current training: [0. 1.]
# Iter 39 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9845
# X_pool shape: (7892, 265), y_train unlabeled: 5892
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 5892
# Labeled: 2000
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4036, type=<class 'numpy.ndarray'>, value=[0.05 0.07 0.19 ... 0.1  0.09 0.09]
#   idx=7402, type=<class 'numpy.ndarray'>, value=[0.05 0.07 0.19 ... 0.1  0.09 0.09]
#   idx=5707, type=<class 'numpy.ndarray'>, value=[0.05 0.07 0.19 ... 0.1  0.09 0.09]
#   idx=2116, type=<class 'numpy.ndarray'>, value=[0.05 0.07 0.19 ... 0.1  0.09 0.09]
#   idx=521, type=<class 'numpy.ndarray'>, value=[0.05 0.07 0.19 ... 0.1  0.09 0.09]
# [UNCERTAINTY] Iter 40 - Classes in current training: [0. 1.]
# Iter 40 [uncertainty] - acc:0.9430, f1:0.9430, auc:0.9812
# X_pool shape: (7892, 265), y_train unlabeled: 5842
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 5842
# Labeled: 2050
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7715, type=<class 'numpy.ndarray'>, value=[0.06 0.08 0.14 ... 0.19 0.05 0.08]
#   idx=443, type=<class 'numpy.ndarray'>, value=[0.06 0.08 0.14 ... 0.19 0.05 0.08]
#   idx=611, type=<class 'numpy.ndarray'>, value=[0.06 0.08 0.14 ... 0.19 0.05 0.08]
#   idx=6243, type=<class 'numpy.ndarray'>, value=[0.06 0.08 0.14 ... 0.19 0.05 0.08]
#   idx=5591, type=<class 'numpy.ndarray'>, value=[0.06 0.08 0.14 ... 0.19 0.05 0.08]
# All class labels: [0 1]
# Initial class distribution: Counter({1: 60, 0: 40})
# [UNCERTAINTY] Iter 1 - Classes in current training: [0. 1.]
# Iter 1 [uncertainty] - acc:0.7913, f1:0.7822, auc:0.9195
# X_pool shape: (7892, 265), y_train unlabeled: 7792
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7792
# Labeled: 100
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7458, type=<class 'numpy.ndarray'>, value=[0.06 0.06 0.   ... 0.05 0.05 0.17]
#   idx=3285, type=<class 'numpy.ndarray'>, value=[0.06 0.06 0.   ... 0.05 0.05 0.17]
#   idx=6038, type=<class 'numpy.ndarray'>, value=[0.06 0.06 0.   ... 0.05 0.05 0.17]
#   idx=6704, type=<class 'numpy.ndarray'>, value=[0.06 0.06 0.   ... 0.05 0.05 0.17]
#   idx=5355, type=<class 'numpy.ndarray'>, value=[0.06 0.06 0.   ... 0.05 0.05 0.17]
# [UNCERTAINTY] Iter 2 - Classes in current training: [0. 1.]
# Iter 2 [uncertainty] - acc:0.9088, f1:0.9084, auc:0.9643
# X_pool shape: (7892, 265), y_train unlabeled: 7742
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7742
# Labeled: 150
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2232, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.   ... 0.08 0.09 0.21]
#   idx=2608, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.   ... 0.08 0.09 0.21]
#   idx=1288, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.   ... 0.08 0.09 0.21]
#   idx=368, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.   ... 0.08 0.09 0.21]
#   idx=7441, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.   ... 0.08 0.09 0.21]
# [UNCERTAINTY] Iter 3 - Classes in current training: [0. 1.]
# Iter 3 [uncertainty] - acc:0.9202, f1:0.9200, auc:0.9678
# X_pool shape: (7892, 265), y_train unlabeled: 7692
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7692
# Labeled: 200
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2231, type=<class 'numpy.ndarray'>, value=[0.09 0.01 0.02 ... 0.06 0.05 0.11]
#   idx=976, type=<class 'numpy.ndarray'>, value=[0.09 0.01 0.02 ... 0.06 0.05 0.11]
#   idx=244, type=<class 'numpy.ndarray'>, value=[0.09 0.01 0.02 ... 0.06 0.05 0.11]
#   idx=4100, type=<class 'numpy.ndarray'>, value=[0.09 0.01 0.02 ... 0.06 0.05 0.11]
#   idx=1802, type=<class 'numpy.ndarray'>, value=[0.09 0.01 0.02 ... 0.06 0.05 0.11]
# [UNCERTAINTY] Iter 4 - Classes in current training: [0. 1.]
# Iter 4 [uncertainty] - acc:0.9042, f1:0.9037, auc:0.9713
# X_pool shape: (7892, 265), y_train unlabeled: 7642
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7642
# Labeled: 250
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=714, type=<class 'numpy.ndarray'>, value=[0.06 0.   0.01 ... 0.06 0.   0.04]
#   idx=118, type=<class 'numpy.ndarray'>, value=[0.06 0.   0.01 ... 0.06 0.   0.04]
#   idx=4090, type=<class 'numpy.ndarray'>, value=[0.06 0.   0.01 ... 0.06 0.   0.04]
#   idx=214, type=<class 'numpy.ndarray'>, value=[0.06 0.   0.01 ... 0.06 0.   0.04]
#   idx=3850, type=<class 'numpy.ndarray'>, value=[0.06 0.   0.01 ... 0.06 0.   0.04]
# [UNCERTAINTY] Iter 5 - Classes in current training: [0. 1.]
# Iter 5 [uncertainty] - acc:0.9133, f1:0.9125, auc:0.9771
# X_pool shape: (7892, 265), y_train unlabeled: 7592
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7592
# Labeled: 300
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=775, type=<class 'numpy.ndarray'>, value=[0.04 0.03 0.01 ... 0.08 0.06 0.08]
#   idx=4021, type=<class 'numpy.ndarray'>, value=[0.04 0.03 0.01 ... 0.08 0.06 0.08]
#   idx=1037, type=<class 'numpy.ndarray'>, value=[0.04 0.03 0.01 ... 0.08 0.06 0.08]
#   idx=5873, type=<class 'numpy.ndarray'>, value=[0.04 0.03 0.01 ... 0.08 0.06 0.08]
#   idx=2470, type=<class 'numpy.ndarray'>, value=[0.04 0.03 0.01 ... 0.08 0.06 0.08]
# [UNCERTAINTY] Iter 6 - Classes in current training: [0. 1.]
# Iter 6 [uncertainty] - acc:0.9213, f1:0.9209, auc:0.9749
# X_pool shape: (7892, 265), y_train unlabeled: 7542
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7542
# Labeled: 350
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7299, type=<class 'numpy.ndarray'>, value=[0.07 0.01 0.04 ... 0.05 0.04 0.05]
#   idx=6897, type=<class 'numpy.ndarray'>, value=[0.07 0.01 0.04 ... 0.05 0.04 0.05]
#   idx=5414, type=<class 'numpy.ndarray'>, value=[0.07 0.01 0.04 ... 0.05 0.04 0.05]
#   idx=2036, type=<class 'numpy.ndarray'>, value=[0.07 0.01 0.04 ... 0.05 0.04 0.05]
#   idx=5751, type=<class 'numpy.ndarray'>, value=[0.07 0.01 0.04 ... 0.05 0.04 0.05]
# [UNCERTAINTY] Iter 7 - Classes in current training: [0. 1.]
# Iter 7 [uncertainty] - acc:0.9133, f1:0.9128, auc:0.9798
# X_pool shape: (7892, 265), y_train unlabeled: 7492
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7492
# Labeled: 400
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3076, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.11 0.07 0.08]
#   idx=4719, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.11 0.07 0.08]
#   idx=881, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.11 0.07 0.08]
#   idx=2370, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.11 0.07 0.08]
#   idx=6214, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.11 0.07 0.08]
# [UNCERTAINTY] Iter 8 - Classes in current training: [0. 1.]
# Iter 8 [uncertainty] - acc:0.9179, f1:0.9174, auc:0.9803
# X_pool shape: (7892, 265), y_train unlabeled: 7442
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7442
# Labeled: 450
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4474, type=<class 'numpy.ndarray'>, value=[0.1  0.06 0.03 ... 0.16 0.13 0.19]
#   idx=4245, type=<class 'numpy.ndarray'>, value=[0.1  0.06 0.03 ... 0.16 0.13 0.19]
#   idx=2665, type=<class 'numpy.ndarray'>, value=[0.1  0.06 0.03 ... 0.16 0.13 0.19]
#   idx=3314, type=<class 'numpy.ndarray'>, value=[0.1  0.06 0.03 ... 0.16 0.13 0.19]
#   idx=3234, type=<class 'numpy.ndarray'>, value=[0.1  0.06 0.03 ... 0.16 0.13 0.19]
# [UNCERTAINTY] Iter 9 - Classes in current training: [0. 1.]
# Iter 9 [uncertainty] - acc:0.9259, f1:0.9256, auc:0.9802
# X_pool shape: (7892, 265), y_train unlabeled: 7392
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7392
# Labeled: 500
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4539, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.22 0.24 0.31]
#   idx=7649, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.22 0.24 0.31]
#   idx=2247, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.22 0.24 0.31]
#   idx=3676, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.22 0.24 0.31]
#   idx=6592, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.03 ... 0.22 0.24 0.31]
# [UNCERTAINTY] Iter 10 - Classes in current training: [0. 1.]
# Iter 10 [uncertainty] - acc:0.9179, f1:0.9174, auc:0.9799
# X_pool shape: (7892, 265), y_train unlabeled: 7342
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7342
# Labeled: 550
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=5542, type=<class 'numpy.ndarray'>, value=[0.02 0.03 0.02 ... 0.22 0.23 0.29]
#   idx=3870, type=<class 'numpy.ndarray'>, value=[0.02 0.03 0.02 ... 0.22 0.23 0.29]
#   idx=880, type=<class 'numpy.ndarray'>, value=[0.02 0.03 0.02 ... 0.22 0.23 0.29]
#   idx=241, type=<class 'numpy.ndarray'>, value=[0.02 0.03 0.02 ... 0.22 0.23 0.29]
#   idx=3896, type=<class 'numpy.ndarray'>, value=[0.02 0.03 0.02 ... 0.22 0.23 0.29]
# [UNCERTAINTY] Iter 11 - Classes in current training: [0. 1.]
# Iter 11 [uncertainty] - acc:0.9247, f1:0.9242, auc:0.9795
# X_pool shape: (7892, 265), y_train unlabeled: 7292
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7292
# Labeled: 600
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=1322, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.05 ... 0.17 0.15 0.2 ]
#   idx=2576, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.05 ... 0.17 0.15 0.2 ]
#   idx=601, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.05 ... 0.17 0.15 0.2 ]
#   idx=1140, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.05 ... 0.17 0.15 0.2 ]
#   idx=4063, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.05 ... 0.17 0.15 0.2 ]
# [UNCERTAINTY] Iter 12 - Classes in current training: [0. 1.]
# Iter 12 [uncertainty] - acc:0.9202, f1:0.9195, auc:0.9762
# X_pool shape: (7892, 265), y_train unlabeled: 7242
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7242
# Labeled: 650
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6601, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.02 ... 0.26 0.19 0.21]
#   idx=3817, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.02 ... 0.26 0.19 0.21]
#   idx=6455, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.02 ... 0.26 0.19 0.21]
#   idx=7248, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.02 ... 0.26 0.19 0.21]
#   idx=2719, type=<class 'numpy.ndarray'>, value=[0.01 0.01 0.02 ... 0.26 0.19 0.21]
# [UNCERTAINTY] Iter 13 - Classes in current training: [0. 1.]
# Iter 13 [uncertainty] - acc:0.9247, f1:0.9242, auc:0.9719
# X_pool shape: (7892, 265), y_train unlabeled: 7192
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7192
# Labeled: 700
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2425, type=<class 'numpy.ndarray'>, value=[0.01 0.02 0.08 ... 0.14 0.15 0.21]
#   idx=1943, type=<class 'numpy.ndarray'>, value=[0.01 0.02 0.08 ... 0.14 0.15 0.21]
#   idx=2064, type=<class 'numpy.ndarray'>, value=[0.01 0.02 0.08 ... 0.14 0.15 0.21]
#   idx=3185, type=<class 'numpy.ndarray'>, value=[0.01 0.02 0.08 ... 0.14 0.15 0.21]
#   idx=5941, type=<class 'numpy.ndarray'>, value=[0.01 0.02 0.08 ... 0.14 0.15 0.21]
# [UNCERTAINTY] Iter 14 - Classes in current training: [0. 1.]
# Iter 14 [uncertainty] - acc:0.9236, f1:0.9230, auc:0.9744
# X_pool shape: (7892, 265), y_train unlabeled: 7142
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7142
# Labeled: 750
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6353, type=<class 'numpy.ndarray'>, value=[0.   0.02 0.1  ... 0.05 0.05 0.06]
#   idx=1416, type=<class 'numpy.ndarray'>, value=[0.   0.02 0.1  ... 0.05 0.05 0.06]
#   idx=2449, type=<class 'numpy.ndarray'>, value=[0.   0.02 0.1  ... 0.05 0.05 0.06]
#   idx=4410, type=<class 'numpy.ndarray'>, value=[0.   0.02 0.1  ... 0.05 0.05 0.06]
#   idx=1512, type=<class 'numpy.ndarray'>, value=[0.   0.02 0.1  ... 0.05 0.05 0.06]
# [UNCERTAINTY] Iter 15 - Classes in current training: [0. 1.]
# Iter 15 [uncertainty] - acc:0.9270, f1:0.9265, auc:0.9781
# X_pool shape: (7892, 265), y_train unlabeled: 7092
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7092
# Labeled: 800
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3657, type=<class 'numpy.ndarray'>, value=[0.03 0.01 0.09 ... 0.15 0.15 0.15]
#   idx=2458, type=<class 'numpy.ndarray'>, value=[0.03 0.01 0.09 ... 0.15 0.15 0.15]
#   idx=3070, type=<class 'numpy.ndarray'>, value=[0.03 0.01 0.09 ... 0.15 0.15 0.15]
#   idx=1974, type=<class 'numpy.ndarray'>, value=[0.03 0.01 0.09 ... 0.15 0.15 0.15]
#   idx=7749, type=<class 'numpy.ndarray'>, value=[0.03 0.01 0.09 ... 0.15 0.15 0.15]
# [UNCERTAINTY] Iter 16 - Classes in current training: [0. 1.]
# Iter 16 [uncertainty] - acc:0.9282, f1:0.9277, auc:0.9775
# X_pool shape: (7892, 265), y_train unlabeled: 7042
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 7042
# Labeled: 850
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6627, type=<class 'numpy.ndarray'>, value=[0.04 0.04 0.09 ... 0.07 0.1  0.14]
#   idx=3137, type=<class 'numpy.ndarray'>, value=[0.04 0.04 0.09 ... 0.07 0.1  0.14]
#   idx=5470, type=<class 'numpy.ndarray'>, value=[0.04 0.04 0.09 ... 0.07 0.1  0.14]
#   idx=921, type=<class 'numpy.ndarray'>, value=[0.04 0.04 0.09 ... 0.07 0.1  0.14]
#   idx=7294, type=<class 'numpy.ndarray'>, value=[0.04 0.04 0.09 ... 0.07 0.1  0.14]
# [UNCERTAINTY] Iter 17 - Classes in current training: [0. 1.]
# Iter 17 [uncertainty] - acc:0.9384, f1:0.9382, auc:0.9830
# X_pool shape: (7892, 265), y_train unlabeled: 6992
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6992
# Labeled: 900
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2364, type=<class 'numpy.ndarray'>, value=[0.02 0.01 0.12 ... 0.15 0.18 0.17]
#   idx=1580, type=<class 'numpy.ndarray'>, value=[0.02 0.01 0.12 ... 0.15 0.18 0.17]
#   idx=847, type=<class 'numpy.ndarray'>, value=[0.02 0.01 0.12 ... 0.15 0.18 0.17]
#   idx=2253, type=<class 'numpy.ndarray'>, value=[0.02 0.01 0.12 ... 0.15 0.18 0.17]
#   idx=53, type=<class 'numpy.ndarray'>, value=[0.02 0.01 0.12 ... 0.15 0.18 0.17]
# [UNCERTAINTY] Iter 18 - Classes in current training: [0. 1.]
# Iter 18 [uncertainty] - acc:0.9282, f1:0.9278, auc:0.9802
# X_pool shape: (7892, 265), y_train unlabeled: 6942
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6942
# Labeled: 950
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2632, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.02 ... 0.09 0.13 0.14]
#   idx=3336, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.02 ... 0.09 0.13 0.14]
#   idx=1561, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.02 ... 0.09 0.13 0.14]
#   idx=5394, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.02 ... 0.09 0.13 0.14]
#   idx=6234, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.02 ... 0.09 0.13 0.14]
# [UNCERTAINTY] Iter 19 - Classes in current training: [0. 1.]
# Iter 19 [uncertainty] - acc:0.9190, f1:0.9186, auc:0.9788
# X_pool shape: (7892, 265), y_train unlabeled: 6892
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6892
# Labeled: 1000
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6015, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.21 0.13 0.12]
#   idx=887, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.21 0.13 0.12]
#   idx=5076, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.21 0.13 0.12]
#   idx=1747, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.21 0.13 0.12]
#   idx=5078, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.21 0.13 0.12]
# [UNCERTAINTY] Iter 20 - Classes in current training: [0. 1.]
# Iter 20 [uncertainty] - acc:0.9270, f1:0.9267, auc:0.9835
# X_pool shape: (7892, 265), y_train unlabeled: 6842
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6842
# Labeled: 1050
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=95, type=<class 'numpy.ndarray'>, value=[0.02 0.07 0.05 ... 0.18 0.11 0.17]
#   idx=6377, type=<class 'numpy.ndarray'>, value=[0.02 0.07 0.05 ... 0.18 0.11 0.17]
#   idx=5369, type=<class 'numpy.ndarray'>, value=[0.02 0.07 0.05 ... 0.18 0.11 0.17]
#   idx=1990, type=<class 'numpy.ndarray'>, value=[0.02 0.07 0.05 ... 0.18 0.11 0.17]
#   idx=1017, type=<class 'numpy.ndarray'>, value=[0.02 0.07 0.05 ... 0.18 0.11 0.17]
# [UNCERTAINTY] Iter 21 - Classes in current training: [0. 1.]
# Iter 21 [uncertainty] - acc:0.9259, f1:0.9255, auc:0.9808
# X_pool shape: (7892, 265), y_train unlabeled: 6792
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6792
# Labeled: 1100
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6533, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.05 ... 0.14 0.07 0.13]
#   idx=3629, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.05 ... 0.14 0.07 0.13]
#   idx=4355, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.05 ... 0.14 0.07 0.13]
#   idx=5940, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.05 ... 0.14 0.07 0.13]
#   idx=5376, type=<class 'numpy.ndarray'>, value=[0.05 0.05 0.05 ... 0.14 0.07 0.13]
# [UNCERTAINTY] Iter 22 - Classes in current training: [0. 1.]
# Iter 22 [uncertainty] - acc:0.9282, f1:0.9277, auc:0.9846
# X_pool shape: (7892, 265), y_train unlabeled: 6742
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6742
# Labeled: 1150
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7728, type=<class 'numpy.ndarray'>, value=[0.03 0.06 0.11 ... 0.15 0.11 0.11]
#   idx=2662, type=<class 'numpy.ndarray'>, value=[0.03 0.06 0.11 ... 0.15 0.11 0.11]
#   idx=1913, type=<class 'numpy.ndarray'>, value=[0.03 0.06 0.11 ... 0.15 0.11 0.11]
#   idx=6077, type=<class 'numpy.ndarray'>, value=[0.03 0.06 0.11 ... 0.15 0.11 0.11]
#   idx=7341, type=<class 'numpy.ndarray'>, value=[0.03 0.06 0.11 ... 0.15 0.11 0.11]
# [UNCERTAINTY] Iter 23 - Classes in current training: [0. 1.]
# Iter 23 [uncertainty] - acc:0.9236, f1:0.9232, auc:0.9827
# X_pool shape: (7892, 265), y_train unlabeled: 6692
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6692
# Labeled: 1200
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=6324, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.12 0.07 0.06]
#   idx=7659, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.12 0.07 0.06]
#   idx=2234, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.12 0.07 0.06]
#   idx=6492, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.12 0.07 0.06]
#   idx=5050, type=<class 'numpy.ndarray'>, value=[0.02 0.04 0.04 ... 0.12 0.07 0.06]
# [UNCERTAINTY] Iter 24 - Classes in current training: [0. 1.]
# Iter 24 [uncertainty] - acc:0.9270, f1:0.9266, auc:0.9824
# X_pool shape: (7892, 265), y_train unlabeled: 6642
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6642
# Labeled: 1250
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7729, type=<class 'numpy.ndarray'>, value=[0.03 0.02 0.04 ... 0.1  0.09 0.18]
#   idx=3462, type=<class 'numpy.ndarray'>, value=[0.03 0.02 0.04 ... 0.1  0.09 0.18]
#   idx=5284, type=<class 'numpy.ndarray'>, value=[0.03 0.02 0.04 ... 0.1  0.09 0.18]
#   idx=1509, type=<class 'numpy.ndarray'>, value=[0.03 0.02 0.04 ... 0.1  0.09 0.18]
#   idx=2112, type=<class 'numpy.ndarray'>, value=[0.03 0.02 0.04 ... 0.1  0.09 0.18]
# [UNCERTAINTY] Iter 25 - Classes in current training: [0. 1.]
# Iter 25 [uncertainty] - acc:0.9145, f1:0.9141, auc:0.9806
# X_pool shape: (7892, 265), y_train unlabeled: 6592
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6592
# Labeled: 1300
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3288, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.03 ... 0.11 0.09 0.16]
#   idx=2676, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.03 ... 0.11 0.09 0.16]
#   idx=2743, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.03 ... 0.11 0.09 0.16]
#   idx=4110, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.03 ... 0.11 0.09 0.16]
#   idx=721, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.03 ... 0.11 0.09 0.16]
# [UNCERTAINTY] Iter 26 - Classes in current training: [0. 1.]
# Iter 26 [uncertainty] - acc:0.9225, f1:0.9221, auc:0.9843
# X_pool shape: (7892, 265), y_train unlabeled: 6542
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6542
# Labeled: 1350
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2269, type=<class 'numpy.ndarray'>, value=[0.02 0.08 0.05 ... 0.07 0.04 0.16]
#   idx=5324, type=<class 'numpy.ndarray'>, value=[0.02 0.08 0.05 ... 0.07 0.04 0.16]
#   idx=914, type=<class 'numpy.ndarray'>, value=[0.02 0.08 0.05 ... 0.07 0.04 0.16]
#   idx=2516, type=<class 'numpy.ndarray'>, value=[0.02 0.08 0.05 ... 0.07 0.04 0.16]
#   idx=3042, type=<class 'numpy.ndarray'>, value=[0.02 0.08 0.05 ... 0.07 0.04 0.16]
# [UNCERTAINTY] Iter 27 - Classes in current training: [0. 1.]
# Iter 27 [uncertainty] - acc:0.9225, f1:0.9221, auc:0.9826
# X_pool shape: (7892, 265), y_train unlabeled: 6492
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6492
# Labeled: 1400
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2459, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.1  ... 0.21 0.18 0.24]
#   idx=7256, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.1  ... 0.21 0.18 0.24]
#   idx=1175, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.1  ... 0.21 0.18 0.24]
#   idx=75, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.1  ... 0.21 0.18 0.24]
#   idx=3641, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.1  ... 0.21 0.18 0.24]
# [UNCERTAINTY] Iter 28 - Classes in current training: [0. 1.]
# Iter 28 [uncertainty] - acc:0.9293, f1:0.9289, auc:0.9849
# X_pool shape: (7892, 265), y_train unlabeled: 6442
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6442
# Labeled: 1450
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=3311, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.09 ... 0.14 0.12 0.2 ]
#   idx=1999, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.09 ... 0.14 0.12 0.2 ]
#   idx=7342, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.09 ... 0.14 0.12 0.2 ]
#   idx=283, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.09 ... 0.14 0.12 0.2 ]
#   idx=288, type=<class 'numpy.ndarray'>, value=[0.04 0.02 0.09 ... 0.14 0.12 0.2 ]
# [UNCERTAINTY] Iter 29 - Classes in current training: [0. 1.]
# Iter 29 [uncertainty] - acc:0.9259, f1:0.9254, auc:0.9844
# X_pool shape: (7892, 265), y_train unlabeled: 6392
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6392
# Labeled: 1500
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7510, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.06 ... 0.16 0.12 0.27]
#   idx=1778, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.06 ... 0.16 0.12 0.27]
#   idx=1830, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.06 ... 0.16 0.12 0.27]
#   idx=2669, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.06 ... 0.16 0.12 0.27]
#   idx=5891, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.06 ... 0.16 0.12 0.27]
# [UNCERTAINTY] Iter 30 - Classes in current training: [0. 1.]
# Iter 30 [uncertainty] - acc:0.9316, f1:0.9312, auc:0.9833
# X_pool shape: (7892, 265), y_train unlabeled: 6342
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6342
# Labeled: 1550
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=7371, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.04 ... 0.15 0.2  0.23]
#   idx=7081, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.04 ... 0.15 0.2  0.23]
#   idx=3933, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.04 ... 0.15 0.2  0.23]
#   idx=2180, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.04 ... 0.15 0.2  0.23]
#   idx=5289, type=<class 'numpy.ndarray'>, value=[0.03 0.03 0.04 ... 0.15 0.2  0.23]
# [UNCERTAINTY] Iter 31 - Classes in current training: [0. 1.]
# Iter 31 [uncertainty] - acc:0.9259, f1:0.9255, auc:0.9812
# X_pool shape: (7892, 265), y_train unlabeled: 6292
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6292
# Labeled: 1600
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=2491, type=<class 'numpy.ndarray'>, value=[0.01 0.06 0.06 ... 0.21 0.11 0.16]
#   idx=948, type=<class 'numpy.ndarray'>, value=[0.01 0.06 0.06 ... 0.21 0.11 0.16]
#   idx=1218, type=<class 'numpy.ndarray'>, value=[0.01 0.06 0.06 ... 0.21 0.11 0.16]
#   idx=947, type=<class 'numpy.ndarray'>, value=[0.01 0.06 0.06 ... 0.21 0.11 0.16]
#   idx=4062, type=<class 'numpy.ndarray'>, value=[0.01 0.06 0.06 ... 0.21 0.11 0.16]
# [UNCERTAINTY] Iter 32 - Classes in current training: [0. 1.]
# Iter 32 [uncertainty] - acc:0.9213, f1:0.9208, auc:0.9816
# X_pool shape: (7892, 265), y_train unlabeled: 6242
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6242
# Labeled: 1650
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=1080, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.06 ... 0.13 0.09 0.11]
#   idx=78, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.06 ... 0.13 0.09 0.11]
#   idx=4699, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.06 ... 0.13 0.09 0.11]
#   idx=4987, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.06 ... 0.13 0.09 0.11]
#   idx=6312, type=<class 'numpy.ndarray'>, value=[0.02 0.05 0.06 ... 0.13 0.09 0.11]
# [UNCERTAINTY] Iter 33 - Classes in current training: [0. 1.]
# Iter 33 [uncertainty] - acc:0.9190, f1:0.9185, auc:0.9819
# X_pool shape: (7892, 265), y_train unlabeled: 6192
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6192
# Labeled: 1700
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=4082, type=<class 'numpy.ndarray'>, value=[0.01 0.03 0.09 ... 0.16 0.13 0.19]
#   idx=1018, type=<class 'numpy.ndarray'>, value=[0.01 0.03 0.09 ... 0.16 0.13 0.19]
#   idx=1318, type=<class 'numpy.ndarray'>, value=[0.01 0.03 0.09 ... 0.16 0.13 0.19]
#   idx=5971, type=<class 'numpy.ndarray'>, value=[0.01 0.03 0.09 ... 0.16 0.13 0.19]
#   idx=950, type=<class 'numpy.ndarray'>, value=[0.01 0.03 0.09 ... 0.16 0.13 0.19]
# [UNCERTAINTY] Iter 34 - Classes in current training: [0. 1.]
# Iter 34 [uncertainty] - acc:0.9213, f1:0.9209, auc:0.9813
# X_pool shape: (7892, 265), y_train unlabeled: 6142
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6142
# Labeled: 1750
# Candidate indices: 7892
# Top 5 selected samples and their scores:
#   idx=5436, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.05 ... 0.12 0.08 0.16]
#   idx=7340, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.05 ... 0.12 0.08 0.16]
#   idx=3911, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.05 ... 0.12 0.08 0.16]
#   idx=1828, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.05 ... 0.12 0.08 0.16]
#   idx=792, type=<class 'numpy.ndarray'>, value=[0.02 0.02 0.05 ... 0.12 0.08 0.16]
# [UNCERTAINTY] Iter 35 - Classes in current training: [0. 1.]
# Iter 35 [uncertainty] - acc:0.9225, f1:0.9221, auc:0.9790
# X_pool shape: (7892, 265), y_train unlabeled: 6092
# Batch size: 50, X_pool shape: (7892, 265)
# Unlabeled in y_train: 6092
# Labeled: 1800
# Candidate indices: 7892
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 31
#      23 for strat in strategies_list:
#      24     results_random[strat] = run_active_learning(
#      25         X_pool_random.copy(), y_pool_random.copy(), X_val_random, y_val_random,
#      26         strategy_type=strat,
#    (...)
#      29         iterations=iterations
#      30     )
# ---> 31     results_time[strat] = run_active_learning(
#      32         X_pool_time.copy(), y_pool_time.copy(), X_val_time, y_val_time,
#      33         strategy_type=strat,
#      34         initial_size=initial_size,
#      35         batch_size=batch_size,
#      36         iterations=iterations
#      37     )
#      39 end_time = time()
#      40 duration = round(end_time - start_time, 2)
#
# Cell In[7], line 107, in run_active_learning(X_pool, y_pool, X_val, y_val, strategy_type, initial_size, batch_size, iterations)
#     104 candidates = np.where(pd.isna(y_train))[0]
#     106 # Call strategy
# --> 107 query_idx, scores = strategy.query(X_pool, y=y_train, clf=model, candidates=candidates, batch_size=batch_size, return_utilities=True)
#     109 print("Top 5 selected samples and their scores:")
#     110 for idx, score in zip(query_idx[:5], scores[:5]):
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\skactiveml\pool\_uncertainty_sampling.py:193, in UncertaintySampling.query(self, X, y, clf, fit_clf, sample_weight, utility_weight, candidates, batch_size, return_utilities)
#     191         clf = clone(clf).fit(X, y, sample_weight)
#     192     else:
# --> 193         clf = clone(clf).fit(X, y)
#     195 # Predict class-membership probabilities.
#     196 probas = clf.predict_proba(X_cand)
#
# File <makefun-gen-597>:2, in fit(self, X, y, sample_weight)
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\skactiveml\classifier\_wrapper.py:113, in SklearnClassifier.fit(self, X, y, sample_weight, **fit_kwargs)
#      88 @match_signature("estimator", "fit")
#      89 def fit(self, X, y, sample_weight=None, **fit_kwargs):
#      90     """Fit the model using `X` as training data and `y` as class labels.
#      91
#      92     Parameters
#    (...)
#     111         The `SklearnClassifier` fitted on the training data.
#     112     """
# --> 113     return self._fit(
#     114         fit_function="fit",
#     115         X=X,
#     116         y=y,
#     117         sample_weight=sample_weight,
#     118         **fit_kwargs,
#     119     )
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\skactiveml\classifier\_wrapper.py:302, in SklearnClassifier._fit(self, fit_function, X, y, sample_weight, **fit_kwargs)
#     298         self.estimator_.partial_fit(
#     299             X=X_lbld, y=y_lbld_inv, **fit_kwargs
#     300         )
#     301     elif fit_function == "fit":
# --> 302         self.estimator_.fit(X=X_lbld, y=y_lbld_inv, **fit_kwargs)
#     303 else:
#     304     if fit_function == "partial_fit":
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\sklearn\ensemble\_forest.py:487, in BaseForest.fit(self, X, y, sample_weight)
#     476 trees = [
#     477     self._make_estimator(append=False, random_state=random_state)
#     478     for i in range(n_more_estimators)
#     479 ]
#     481 # Parallel loop: we prefer the threading backend as the Cython code
#     482 # for fitting the trees is internally releasing the Python GIL
#     483 # making threading more efficient than multiprocessing in
#     484 # that case. However, for joblib 0.12+ we respect any
#     485 # parallel_backend contexts set at a higher level,
#     486 # since correctness does not rely on using threads.
# --> 487 trees = Parallel(
#     488     n_jobs=self.n_jobs,
#     489     verbose=self.verbose,
#     490     prefer="threads",
#     491 )(
#     492     delayed(_parallel_build_trees)(
#     493         t,
#     494         self.bootstrap,
#     495         X,
#     496         y,
#     497         sample_weight,
#     498         i,
#     499         len(trees),
#     500         verbose=self.verbose,
#     501         class_weight=self.class_weight,
#     502         n_samples_bootstrap=n_samples_bootstrap,
#     503         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     504     )
#     505     for i, t in enumerate(trees)
#     506 )
#     508 # Collect newly grown trees
#     509 self.estimators_.extend(trees)
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\sklearn\utils\parallel.py:139, in _FuncWrapper.__call__(self, *args, **kwargs)
#     137     config = {}
#     138 with config_context(**config):
# --> 139     return self.function(*args, **kwargs)
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\sklearn\ensemble\_forest.py:189, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     186     elif class_weight == "balanced_subsample":
#     187         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 189     tree._fit(
#     190         X,
#     191         y,
#     192         sample_weight=curr_sample_weight,
#     193         check_input=False,
#     194         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     195     )
#     196 else:
#     197     tree._fit(
#     198         X,
#     199         y,
#    (...)
#     202         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     203     )
#
# File c:\Users\gl8304\Documents\Projekti\IJS\smart-energy-ea\venv-smart-energy\Lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# ==============================================
# 6) Plot and Save Figures
# ==============================================

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# random split plot
plt.figure(figsize=(10,6))
for strat in strategies_list:
    accs = [m["accuracy"] for m in results_random[strat]]
    plt.plot(accs, label=strat)
plt.title("Active Learning Strategies - Random Split")
plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.legend()
fig = plt.gcf()
plot_filename = f"../figures/al_strategy_comparison_random_{timestamp}.png"
fig.savefig(plot_filename)
print(f"Plot saved as: {plot_filename}")
plt.show()

# sequential split plot
plt.figure(figsize=(10,6))
for strat in strategies_list:
    accs = [m["accuracy"] for m in results_time[strat]]
    plt.plot(accs, label=strat)
plt.title("Active Learning Strategies - Sequential Split")
plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.legend()
fig = plt.gcf()
plot_filename = f"../figures/al_strategy_comparison_time_{timestamp}.png"
fig.savefig(plot_filename)
print(f"Plot saved as: {plot_filename}")
plt.show()
# Out:
# Plot saved as: ../figures/al_strategy_comparison_random_20250715_115744.png
# Plot saved as: ../figures/al_strategy_comparison_time_20250715_115744.png

# %%
# ==============================================
# 7) Save Results to CSV
# ==============================================

total_labeled = initial_size + iterations * batch_size
duration_sec = duration

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
csv_path = f"../tables/active_learning_runs_{timestamp}.csv"

fieldnames = [
    "timestamp", "strategy_type", "split_type", "iterations", "test_size",
    "initial_size", "batch_size", "total_labeled_samples", 
    "accuracy_final", "accuracy_mean", "accuracy_std", 
    "precision_mean", "recall_mean", "f1_mean", "roc_auc_mean", 
    "duration_sec"
]

with open(csv_path, mode="w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

    # random split
    for strat, metrics in results_random.items():
        accuracy_vals = [m["accuracy"] for m in metrics]
        precision_vals = [m["precision"] for m in metrics]
        recall_vals = [m["recall"] for m in metrics]
        f1_vals = [m["f1"] for m in metrics]
        roc_auc_vals = [m["roc_auc"] for m in metrics]
        
        writer.writerow({
            "timestamp": timestamp,
            "strategy_type": strat,
            "split_type": "random",
            "iterations": iterations,
            "test_size": test_size,
            "initial_size": initial_size,
            "batch_size": batch_size,
            "total_labeled_samples": total_labeled,
            "accuracy_final": accuracy_vals[-1],
            "accuracy_mean": np.mean(accuracy_vals),
            "accuracy_std": np.std(accuracy_vals),
            "precision_mean": np.mean(precision_vals),
            "recall_mean": np.mean(recall_vals),
            "f1_mean": np.mean(f1_vals),
            "roc_auc_mean": np.mean(roc_auc_vals),
            "duration_sec": duration_sec
        })

    # time-based split
    for strat, metrics in results_time.items():
        accuracy_vals = [m["accuracy"] for m in metrics]
        precision_vals = [m["precision"] for m in metrics]
        recall_vals = [m["recall"] for m in metrics]
        f1_vals = [m["f1"] for m in metrics]
        roc_auc_vals = [m["roc_auc"] for m in metrics]
        
        writer.writerow({
            "timestamp": timestamp,
            "strategy_type": strat,
            "split_type": "sequential",
            "iterations": iterations,
            "test_size": test_size,
            "initial_size": initial_size,
            "batch_size": batch_size,
            "total_labeled_samples": total_labeled,
            "accuracy_final": accuracy_vals[-1],
            "accuracy_mean": np.mean(accuracy_vals),
            "accuracy_std": np.std(accuracy_vals),
            "precision_mean": np.mean(precision_vals),
            "recall_mean": np.mean(recall_vals),
            "f1_mean": np.mean(f1_vals),
            "roc_auc_mean": np.mean(roc_auc_vals),
            "duration_sec": duration_sec
        })

print(f"Summary table saved to: {csv_path}")


# save also to .xlsx
df = pd.read_csv(csv_path)
xlsx_path = csv_path.replace(".csv", ".xlsx")
df.to_excel(xlsx_path, index=False)

print(f"Excel file also saved to: {xlsx_path}")
# Out:
# Summary table saved to: ../tables/active_learning_runs_2025-07-15_11-57-45.csv
# Excel file also saved to: ../tables/active_learning_runs_2025-07-15_11-57-45.xlsx
